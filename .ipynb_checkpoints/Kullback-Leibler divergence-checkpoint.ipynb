# %% [markdown]
# **Machine Scientist Libraries** and additional libraries

# %%
import sys
import numpy as np 
import pandas as pd
import warnings
import sympy 
import matplotlib as plt
warnings.filterwarnings('ignore')

from copy import deepcopy
from ipywidgets import IntProgress
from IPython.display import display

sys.path.append('./')
sys.path.append('./Prior/')
from mcmc import *
from parallel import *
from fit_prior import read_prior_par

#File related libraries
from expression_writter import *

#Writing files libraries
import re
from file_creator import *
import os
import pickle

# %% [markdown]
# Adding the file of a function to be studied. Several functions will be repeated and we will only count them onece, so we first have to filter that.

# %%
filepath = './Results_Leo/ 3.39*x**3 + 2.12*x**2 + 1.78*x_nv1_np10_mean0_stddev0.1.txt'
expressions = set()

with open(filepath, 'r') as file:
    for line in file:
        parts = line.split('||')
        desc_length = float(parts[1])
        expression = str(parts[2])
        tuple = (desc_length, expression)
        expressions.add(tuple)

#create another file where the expressions and desc. length will be written
dataFileName = os.path.basename(filepath)
newname = f"Filetered_{dataFileName}"
folder = "./Results_Leo/Filtered_Datasets/"
newPath = os.path.join(folder,newname)

with open(newPath, 'w') as file:
    for elem in expressions:
        file.write(f"{elem[0]}||{elem[1]}\n")

# %% [markdown]
# Variables and parameters config

# %%
XLABS = ['x','z'] #Change to just x if one variable models
parameters = ['_a%d_' % i for i in range(13)]

#creating empty tree and probtree
model = Tree(
    variables = XLABS,
    parameters = parameters,
)

#Probability tree
Tree_prob =ProbTree(
    tree = model,
) 

#name of the file where the prob_tree will be stored

treeStorageFileName = f"{os.path.basename(filepath)}_GREEDY"
location = "./KL/Probabilty_Trees/"
objFile = os.path.join(location, treeStorageFileName)

# %%
#Kullback-Leibler Divergence computation
def KLDivergence(filepath, probTree):
    D = 0
    with open(filepath, 'r') as file:
        for line in file:
            line = line.strip()
            parts = line.split('||')
            desc_length = float(parts[0])
            expression = str(parts[1])
            #generate tree for the expression
            exp_tree = Tree(
                variables = XLABS,
                from_string = expression,
            )
            exp_tree.parameters = parameters
            probTree.tree_change(exp_tree)
            exp_prob_tree = probTree.pr_tree()
            D += np.exp(-desc_length)* np.log(np.exp(-desc_length) / exp_prob_tree)
        return D
D = KLDivergence(filepath = newPath, probTree = Tree_prob)
print("Initial KL Divergence: " + str(D))
# Out:
# Initial KL Divergence: 0.00037788410244808885

# %% [markdown]
# Now, a copy of the current Probability Tree will be walked through and the probabilites of a node chosen at random will be changed (the other probabilites will be accordingly adapted). Then, the KL Divergence will be computed again, and if its value is smaller then the change will be accepted, otherwise rejected.

# %%
##### Kullback-Leibler Divergence random improvement
def KL_improve(Tree_prob, D):
    Tree_copy = Tree_prob.tree_copy()
    Tree_copy.modify_random_prob()
    newD = KLDivergence(filepath= newPath, probTree=Tree_copy)
    if abs(newD) < abs(D):
        D = newD
        Tree_prob = Tree_copy #replace with the better prob tree
        
    return D, Tree_prob, newD #record all values that are achieved with this procedure, and update the tree in case of improvement

# %% [markdown]
# Files with the evolution of the KL Divergence will be saved and stored in the folder named `KL`.

# %%
filename = os.path.basename(filepath)
filename_no_extension = os.path.splitext(filename)[0] #remove the .txt
new_filename = f"KL_{filename_no_extension}_Large_GREEDY"
folder = './KL/KL_Evolution/'
new_filepath = os.path.join(folder, new_filename)
N = 25000
initialD = D

with open(new_filepath, 'w') as f:
    f.write(f"{D}\n")
    bar = IntProgress(min = 0, max = N, description='Running:')
    display(bar)
    for i in range(0,N):
        D, Tree_prob, newD =  KL_improve(Tree_prob = Tree_prob, D = D)
        f.write(f"{newD}\n")
        bar.value += 1
        if i % 1000 == 0:
            f.flush()
            #Now we add the last probability tree we have
            with open(objFile, 'wb') as file:
                pickle.dump(Tree_prob, file)

print('Finished')
# Out:
# IntProgress(value=0, description='Running:', max=1000)
# Trying to change node <mcmc.ProbNode object at 0x77b5d3df65f0>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc2230>, operation sqrt
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d38520>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d295bdc0>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c2500>, operation pow3
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33d9420>, operation cosh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33bf6d0>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47fb370>, operation pow3
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3defbb0>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33da620>, operation cosh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b2f20>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2944250>, operation pow2
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47397e0>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cfe20>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3da5d20>, operation cos
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d38220>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2944af0>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a1d20>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c2b60>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3deccd0>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d6e866b0>, operation cos
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cfe20>, operation pow3
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a0bb0>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d295ad70>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3da47f0>, operation exp
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291e7d0>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d6e85f30>, operation pow3
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc3730>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d1f30dc0>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33bdb10>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291eec0>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33392d0>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3339750>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29326e0>, operation *
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33dbf70>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d333ae60>, operation pow3
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d333ac20>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d4794520>, operation pow2
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3308310>, operation pow2
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cd600>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d1f31990>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cd1e0>, operation pow3
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2946bf0>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d295a290>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2947c10>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291ceb0>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3372110>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc3520>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47fb340>, operation **
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291c0d0>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2946c20>, operation -
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b2b90>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2933fa0>, operation pow3
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d3bf70>, operation sinh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b2f20>, operation sqrt
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d5128640>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d330ad70>, operation log
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291e020>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b38e0>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d1f23850>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d1f22bf0>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3decd00>, operation pow3
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a3bb0>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51f0c40>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33d9570>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3309210>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2945870>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d6e86290>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51ab280>, operation sinh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29324d0>, operation tanh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d1f32560>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d1f32710>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2930730>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b651148f70>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b3b80>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29772b0>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291dc90>, operation sinh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3df5db0>, operation *
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d4796080>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2930940>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d4796500>, operation exp
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a2bf0>, operation pow3
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33db610>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dee200>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b1600>, operation -
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3370430>, operation **
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3def7c0>, operation sqrt
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47cf670>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d3b0a0>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d2b7c0>, operation tanh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2946140>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d473b3a0>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d39300>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d5181b40>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d4739bd0>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b2ef0>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3339de0>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2974610>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2946b90>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2975d50>, operation tanh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c1150>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3da4940>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d38880>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2944640>, operation tanh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3ded4e0>, operation tanh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3da4df0>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d4760fa0>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2976980>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc2ec0>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a1d80>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2932500>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d2aec0>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b2410>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29446d0>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2930ee0>, operation +
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b1ab0>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b0430>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cd930>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d2aa40>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c1660>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d6e873a0>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d4796350>, operation -
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b3c40>, operation +
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d296d9c0>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29757b0>, operation -
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b2170>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47ccf10>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51ab160>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc2e00>, operation sin
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b1360>, operation -
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33dbf40>, operation +
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3da8fa0>, operation cos
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51a8490>, operation **
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29ce3e0>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47f8370>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c0a00>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33dbc10>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2977d90>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2931d20>, operation abs
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33be140>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d4794850>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51a9510>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cf400>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d6e87250>, operation *
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33096f0>, operation log
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3df7ee0>, operation cos
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47f8eb0>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d333a050>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3df7fa0>, operation -
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3df73d0>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dab940>, operation pow3
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc16c0>, operation cos
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d4797ee0>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51f0d90>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d5183880>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29ce9e0>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d330a890>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d6e87df0>, operation abs
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47cc370>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d296ca90>, operation fac
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cdbd0>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc1870>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291e260>, operation sinh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29ceb00>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d2afe0>, operation cosh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d333b640>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cf1f0>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51c1480>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d330b4f0>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33bd330>, operation cos
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d2bc40>, operation *
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc3430>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3defee0>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c1f60>, operation **
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c3ac0>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d333aaa0>, operation /
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d296f7c0>, operation cos
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d5128550>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33097b0>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d5e620>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3372f20>, operation pow3
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d38430>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d38e20>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc10c0>, operation cos
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51f0820>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b1240>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b1fc0>, operation fac
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d5180dc0>, operation cosh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a22f0>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d4794340>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29746a0>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d296c3d0>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3df55d0>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291fca0>, operation /
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29749a0>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51c25f0>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c0460>, operation tanh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a11e0>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a3a30>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d296f1c0>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29775b0>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3309fc0>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29ce5c0>, operation fac
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a2fe0>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29768c0>, operation -
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d2a110>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d4797b80>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b2860>, operation sqrt
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51a95a0>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3373190>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51f3520>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33bdfc0>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3373e80>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3372fe0>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2945750>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3373970>, operation pow3
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d330a380>, operation sqrt
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d4763c70>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33bcd90>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c1750>, operation cos
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc2860>, operation -
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2977730>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d333ab60>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cfe80>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29332e0>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d296f310>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51f3b50>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47cd810>, operation exp
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d296cb80>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3da7400>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b2080>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc19f0>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dab340>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33bd600>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc1000>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291e290>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d65ca3b0>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d473a320>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33bffd0>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d5fa30>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d6e86b30>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d333b640>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47f84c0>, operation sinh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d514f160>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d333b340>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d296e110>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2977f10>, operation pow3
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47f8eb0>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b65114ad10>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d4761000>, operation cos
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29457e0>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33389a0>, operation abs
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3df67d0>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d5180ac0>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d28be0>, operation tanh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cdb70>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2975a20>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c1b10>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d296dc60>, operation **
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33bc910>, operation log
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2932230>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33dab30>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47f8370>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc04c0>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33da6b0>, operation cos
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2945cf0>, operation **
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3da7eb0>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc32b0>, operation pow3
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51a9cc0>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47fb340>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a17b0>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d296e830>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d28640>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cc4c0>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d29f60>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3ded7e0>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3339450>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d38c40>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a1f30>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291c430>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d5ca30>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51280a0>, operation cos
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33706a0>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2931b40>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d4763010>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3372020>, operation pow3
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cc310>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d6e87400>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29ccd60>, operation pow3
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d296cb50>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51f3610>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2977bb0>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33d80a0>, operation cos
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33be470>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d5d090>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a00a0>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47fbbe0>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a2d10>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cc850>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b65114b790>, operation /
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc17b0>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d333a110>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d296c9a0>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51aa740>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d333ba90>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d333a2c0>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b2620>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33d9de0>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33bcbb0>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d38880>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d2bfd0>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2977d60>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a0e50>, operation cos
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d473a3e0>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2945210>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47f9c00>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3da6a70>, operation cos
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a05e0>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d514f5b0>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291c580>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d4739ab0>, operation +
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b1bd0>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33bdcf0>, operation cos
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3371d80>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33d9f90>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2977a00>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cca00>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d296dbd0>, operation pow3
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51a8100>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51f2bf0>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3da9810>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d6e86b90>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cec80>, operation +
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c08e0>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc33d0>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c0b50>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2945ae0>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d330a530>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b0280>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47f9180>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d6e85a50>, operation -
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2933790>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c1420>, operation +
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33beb90>, operation pow3
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc2890>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d514ca90>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b1bd0>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33d9570>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51aa0b0>, operation exp
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3372800>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d39600>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3309420>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2932fb0>, operation sin
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d5183430>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d295d0>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b1e70>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29322c0>, operation sin
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2931810>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc1900>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c37f0>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3def7c0>, operation -
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d3a770>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51f1ed0>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a2710>, operation fac
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b2680>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33dbfa0>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d3b580>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3da75e0>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d4795f00>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2931c00>, operation fac
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a1660>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47ce5f0>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d512a950>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47fb8e0>, operation +
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51f2ec0>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d4795360>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291db10>, operation cosh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33386a0>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d5ff10>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a2710>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d330bd30>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d3a6e0>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d2b070>, operation sin
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc3a30>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cd1b0>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc38b0>, operation cosh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33bca90>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3338220>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3373a60>, operation sinh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d6e86cb0>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51aaec0>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b2650>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d330b160>, operation pow3
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33bf9d0>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dee260>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51aa620>, operation pow3
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dee1d0>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d38760>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47ce1d0>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cd420>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc19f0>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33d9a50>, operation sqrt
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2975330>, operation pow3
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47f9120>, operation cos
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2932b60>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2933e50>, operation cosh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d4794130>, operation *
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291e200>, operation exp
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d296e7d0>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33d94b0>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3373c40>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a1210>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3308a00>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d5e290>, operation sinh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d6e873a0>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b0880>, operation tan
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47fa5f0>, operation tanh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51f1ba0>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d2aad0>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29765f0>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33daa40>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b1810>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2947d30>, operation pow3
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3df4610>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d5181630>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a3280>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d29db0>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d3a920>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291d9c0>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51a9cf0>, operation fac
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b15d0>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33bcd90>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51a8130>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29327a0>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29ce200>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2977160>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d39780>, operation pow3
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33da800>, operation cos
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3da5960>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d5d960>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51f3610>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cca90>, operation cos
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3da94b0>, operation +
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33bd0f0>, operation exp
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c32b0>, operation fac
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b65114b8b0>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3da4d30>, operation fac
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51f28f0>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dab1f0>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2944a90>, operation cos
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b2ec0>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d28730>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3da7df0>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3da9240>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47960b0>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cfdf0>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3ded960>, operation pow3
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29302b0>, operation pow2
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d473b2b0>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2975540>, operation cos
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291c5e0>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c3550>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33bdf90>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3da5570>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51a9780>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d473a950>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47f8820>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cebc0>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33721d0>, operation +
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51c2290>, operation pow3
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a26b0>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2974bb0>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29469e0>, operation tan
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51abfa0>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d4794bb0>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3daa530>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2974970>, operation exp
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d4797ee0>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33d9ff0>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b1de0>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2977880>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d333ada0>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d5182c50>, operation -
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33bfd60>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d4796f20>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47966e0>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2944280>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d5f910>, operation cosh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc18d0>, operation cosh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d514c640>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d3b730>, operation abs
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291e3b0>, operation sinh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2945330>, operation -
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33bfca0>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51aa200>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47cc6a0>, operation /
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d296ea70>, operation sqrt
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cd930>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33736d0>, operation pow2
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3308520>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2930850>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47cd8d0>, operation cos
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33bed70>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33097b0>, operation sqrt
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33735b0>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b2b30>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d2a920>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d2b610>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2932c20>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47ccfd0>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51839d0>, operation abs
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47cf310>, operation cos
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33bfa90>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2977a60>, operation cosh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51c17e0>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c2e30>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51c01f0>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d4796bf0>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2944ee0>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33d91b0>, operation pow2
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29ce5c0>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33d8ee0>, operation cosh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33bd690>, operation +
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291d300>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cd3f0>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d5181930>, operation log
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d384f0>, operation abs
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47f9b70>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc1f90>, operation sinh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d2bd90>, operation -
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3370a60>, operation pow3
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3daaa70>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3309540>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3da53f0>, operation pow2
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3338460>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2946a10>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d514c190>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d3a2c0>, operation sinh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dabc40>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c0ca0>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2944700>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47cf340>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cf820>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3da5db0>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d29c90>, operation tanh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3df61d0>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2931ed0>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33398a0>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29333d0>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291d240>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d296e7d0>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29777c0>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d296f520>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33db580>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2932050>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d6e87d90>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47f8b50>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d4762650>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b65114bdf0>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d296f8b0>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d296cd30>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b65114bac0>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b2e00>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2944100>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d5cbe0>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a26e0>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d6e858d0>, operation pow3
#
# ...
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d5e800>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3daa7d0>, operation fac
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d330a470>, operation log
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51c33d0>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c0b50>, operation sinh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291ca30>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d3a770>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c0550>, operation pow3
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2931ba0>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2974f70>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c2980>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291e3e0>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3338550>, operation **
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2932ef0>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c3340>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c1000>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3da8880>, operation tanh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d6e85b10>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3da6aa0>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d4794cd0>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33081c0>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d4760ca0>, operation sqrt
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d2a7a0>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33d8610>, operation pow2
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33bdf90>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d1f27850>, operation **
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d473b100>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291c670>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b36d0>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d1f25930>, operation cos
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a2ef0>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2975990>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47fb160>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dab130>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc1e10>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a2530>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33d8e20>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47fad40>, operation +
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3decee0>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b2b30>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47fb340>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d5128a30>, operation pow3
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3da5930>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c1fc0>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47f89a0>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33bef20>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d4763bb0>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33db610>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d29f90>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c3760>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b1d20>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a1e40>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cf760>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c1030>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc0df0>, operation cos
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3309540>, operation -
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a0460>, operation *
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29329b0>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cf190>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33d9780>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3df5000>, operation tan
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47946d0>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51c17e0>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291da50>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2944400>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3339630>, operation pow3
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3309180>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2931330>, operation sqrt
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc1330>, operation exp
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3371600>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2976f80>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b1a80>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291eec0>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33bf9d0>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29760e0>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3339b10>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47956f0>, operation pow3
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3daacb0>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291e6b0>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29ccd90>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33d89a0>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc2f50>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3da65f0>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291e7d0>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d333b5e0>, operation cos
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51ab2b0>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d512a7a0>, operation sqrt
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3da7580>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2945b70>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a1d20>, operation log
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cce20>, operation sqrt
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3df6800>, operation *
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d1f25ab0>, operation cos
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d396f0>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3309060>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3309a50>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d330b5e0>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33be3b0>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d6e874c0>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33bc790>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33da2f0>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291eb00>, operation cos
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3daa080>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291ea10>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d1f27cd0>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2930970>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a0e80>, operation cosh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3339450>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a3370>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dee680>, operation pow3
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2975360>, operation **
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d1f25720>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51ab970>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51c3370>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b2860>, operation /
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291dbd0>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a3190>, operation pow3
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d514f850>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33723e0>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51a9780>, operation cos
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47610f0>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33723e0>, operation sqrt
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47387f0>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dab1f0>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33be0e0>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d2a290>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2975b10>, operation abs
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d330bcd0>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cfc40>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c3e20>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a0dc0>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b1720>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d330ace0>, operation *
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dee1d0>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29769b0>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d2b910>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29cd720>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33d9780>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c0e20>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dc1e40>, operation *
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33da290>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29308e0>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3373610>, operation cos
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2931f00>, operation -
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d330a650>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2932200>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3309330>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2974f70>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47ceb90>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d285e0>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d330ab60>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b35e0>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b0940>, operation fac
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33733d0>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d51812d0>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d330ab60>, operation tan
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33a2f20>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d38fa0>, operation -
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d473abc0>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c3eb0>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33d8a90>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2974c70>, operation /
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d333abc0>, operation +
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29448b0>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2975f60>, operation cosh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b2440>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3371480>, operation cos
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3dec6a0>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3338520>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33bd1b0>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d473bc10>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291e1a0>, operation exp
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3370eb0>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d39b70>, operation sin
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d1f26c80>, operation **
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d330a4a0>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47964a0>, operation +
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d514c370>, operation sinh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3d38190>, operation tanh
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33c22c0>, operation cos
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d514d360>, operation sqrt
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d291fc10>, operation pow2
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29ce170>, operation tanh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d5182dd0>, operation -
#
# The change was accepted
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d47f8760>, operation abs
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d3da6d10>, operation *
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b1540>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d33d9fc0>, operation cosh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d4794430>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d29b2380>, operation log
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d1f274c0>, operation sinh
#
# Trying to change node <mcmc.ProbNode object at 0x77b5d2976110>, operation **
#
# Finished

# %%
#Now we add the last probability tree we have
with open(objFile, 'wb') as f:
    pickle.dump(Tree_prob, f)

# %% [markdown]
# Plot the evolution of the KL divergence

# %%
steps = np.arange(0,N+1,1)
KL = []

with open(new_filepath, 'r') as f:
    for line in f:
        KL.append(float(line.strip()))

steps = np.arange(0,len(KL),1)

# Name formatting
parts = filename_no_extension.split("_")
raw_function = parts[0]

# Plot formatting
function = raw_function.replace("**", "^").replace("*", "")
'''
nvar = parts[1].replace("nv", "")  # Número de variables
nparam = parts[2].replace("np", "")  # Número de parámetros
mean = parts[3].replace("mean", "")  # Media
stddev = parts[4].replace("stddev", "")  # Desviación estándar

# LaTeX format title

title = rf"$\text{{KL Divergence evolution of }} {function}$ " + "\n" \
        rf"$n_{{\text{{variables}}}}={nvar}, n_{{\text{{parameters}}}}={nparam}, " \
        rf"\epsilon \sim \mathcal{{N}}({mean}, {stddev})$"
'''
title = "KL Divergence evolution of tree expressions generated with only the prior"
output_folder = "./KL/Figures/"
output_filename = f"KL_evolution_{filename_no_extension}_GREEDY.png"
output_path = os.path.join(output_folder, output_filename)

plt.plot(steps, KL, label="KL Divergence", color="blue")
plt.xlabel("Steps", fontsize=14)
plt.ylabel("KL", fontsize=14)
plt.title(title, fontsize=16, pad=20)
plt.legend(loc="best", fontsize=10)
plt.grid(True)
plt.savefig(output_path, dpi = 300, bbox_inches = 'tight')


plt.show()

# %%
Tree_prob.root.prob_list
# Out:
# {'x': 0.03333333333333333,
#  'z': 0.03333333333333333,
#  '_a0_': 0.03333333333333333,
#  '_a1_': 0.03333333333333333,
#  '_a2_': 0.03333333333333333,
#  '_a3_': 0.03333333333333333,
#  '_a4_': 0.03333333333333333,
#  '_a5_': 0.03333333333333333,
#  '_a6_': 0.03333333333333333,
#  '_a7_': 0.03333333333333333,
#  '_a8_': 0.03333333333333333,
#  '_a9_': 0.03333333333333333,
#  '_a10_': 0.03333333333333333,
#  '_a11_': 0.03333333333333333,
#  '_a12_': 0.03333333333333333,
#  'sin': 0.027777777777777776,
#  'cos': 0.027777777777777776,
#  'tan': 0.027777777777777776,
#  'exp': 0.027777777777777776,
#  'log': 0.027777777777777776,
#  'sinh': 0.027777777777777776,
#  'cosh': 0.027777777777777776,
#  'tanh': 0.027777777777777776,
#  'pow2': 0.027777777777777776,
#  'pow3': 0.027777777777777776,
#  'abs': 0.027777777777777776,
#  'sqrt': 0.027777777777777776,
#  'fac': 0.027777777777777776,
#  '-': 0.027777777777777776,
#  '+': 0.027777777777777776,
#  '*': 0.027777777777777776,
#  '/': 0.027777777777777776,
#  '**': 0.027777777777777776}
